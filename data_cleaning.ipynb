# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Rano's PC\Machine\💻data-science-projects\cricket talent prediction\cricket_data.csv",encoding='ISO-8859-1')

# %%
data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0                                         Player_URL
# 0  21367  86.23  49  96  20  http://stats.espncricinfo.com/ci/content/playe...
# 1  18048  78.86  25  93  15  http://stats.espncricinfo.com/ci/content/playe...
# 2  17046  80.39  30  82  20  http://stats.espncricinfo.com/ci/content/playe...
# 3  14725   91.2  28  68  34  http://stats.espncricinfo.com/ci/content/playe...
# 4  16020  78.96  19  77  28  http://stats.espncricinfo.com/ci/content/playe...

# %%
data.shape
# Out:
# (2589, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      2589 non-null   object
#  1   Span        2589 non-null   object
#  2   Mat         2589 non-null   int64
#  3   Inns        2589 non-null   object
#  4   NO          2589 non-null   object
#  5   Runs        2589 non-null   object
#  6   HS          2589 non-null   object
#  7   Ave         2589 non-null   object
#  8   BF          2589 non-null   object
#  9   SR          2589 non-null   object
#  10  100         2589 non-null   object
#  11  50          2589 non-null   object
#  12  0           2589 non-null   object
#  13  Player_URL  2589 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 283.3+ KB

# %%
data.isnull().sum()
# Out:
# Player        0
# Span          0
# Mat           0
# Inns          0
# NO            0
# Runs          0
# HS            0
# Ave           0
# BF            0
# SR            0
# 100           0
# 50            0
# 0             0
# Player_URL    0
# dtype: int64

# %%
data=data[data['Mat']>100]

# %%
data.shape
# Out:
# (260, 14)

# %%
data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0                                         Player_URL
# 0  21367  86.23  49  96  20  http://stats.espncricinfo.com/ci/content/playe...
# 1  18048  78.86  25  93  15  http://stats.espncricinfo.com/ci/content/playe...
# 2  17046  80.39  30  82  20  http://stats.espncricinfo.com/ci/content/playe...
# 3  14725   91.2  28  68  34  http://stats.espncricinfo.com/ci/content/playe...
# 4  16020  78.96  19  77  28  http://stats.espncricinfo.com/ci/content/playe...

# %%
data.drop(columns=['Player_URL'],inplace=True)

# %%
data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0
# 0  21367  86.23  49  96  20
# 1  18048  78.86  25  93  15
# 2  17046  80.39  30  82  20
# 3  14725   91.2  28  68  34
# 4  16020  78.96  19  77  28

# %%
data.rename(columns={'Mat':'matches','Inns':'innings','NO':'not outs','Runs':'runs','HS':'highest score','Ave':'average','BF':'balls faced','SR':'strike rate',
                     '100':'centuries','50':'half centuries','0':'ducks'},inplace=True)

# %%
data['country']=data['Player'].str.split("(",expand=True)[1]

# %%
data['country']=data['country'].str.replace(")","")

# %%
data['country'].value_counts()
# Out:
# country
# WI                29
# INDIA             26
# PAK               26
# AUS               25
# SL                20
# NZ                20
# ENG               17
# SA                14
# ZIM               12
# BDESH              8
# Afr/SA             7
# Asia/INDIA         7
# Asia/SL            5
# IRE                5
# AUS/ICC            5
# Afr/ZIM            4
# ENG/ICC            3
# Asia/PAK           3
# Asia/BDESH         3
# ICC/NZ             3
# AFG                2
# Afr/KENYA          2
# ICC/WI             2
# Asia/ICC/INDIA     2
# Asia/ICC/PAK       2
# Asia/ICC/SL        2
# Afr/ICC/SA         2
# ENG/IRE            1
# AUS/SA             1
# KENYA              1
# ICC/SA             1
# Name: count, dtype: int64

# %%
def clean_country(raw):
    ignore = ['Afr', 'Asia', 'ICC', 'XI']
    parts = raw.split('/')
    
    # Filter out generic tokens
    parts = [p.strip().upper() for p in parts if p.strip().upper() not in ignore]
    
    # Handle specific combinations
    if raw == 'ENG/IRE':
        return 'IRE'
    elif raw == 'AUS/SA':
        return 'SA'
    
    # If only one valid country remains
    if len(parts) == 1:
        return parts[0]
    elif len(parts) >= 2:
        return parts[-1]  # default: keep the last valid country
    else:
        return None

# %%
data['country']=data['country'].apply(clean_country)

# %%
data['country'].value_counts()
# Out:
# country
# INDIA    35
# PAK      31
# WI       31
# AUS      30
# SL       27
# SA       25
# NZ       23
# ENG      20
# ZIM      16
# BDESH    11
# IRE       6
# KENYA     3
# AFG       2
# Name: count, dtype: int64

# %%
country_map = {
    'INDIA': 'India',
    'PAK': 'Pakistan',
    'WI': 'West Indies',
    'AUS': 'Australia',
    'SL': 'Sri Lanka',
    'SA': 'South Africa',
    'NZ': 'New Zealand',
    'ENG': 'England',
    'ZIM': 'Zimbabwe',
    'BDESH': 'Bangladesh',
    'IRE': 'Ireland',
    'KENYA': 'Kenya',
    'AFG': 'Afghanistan'
}

# %%
data['country']=data['country'].map(country_map)

# %%
data.head()
# Out:
#                         Player       Span  matches innings not outs   runs  \
# 0         SR Tendulkar (INDIA)  1989-2012      463     452       41  18426
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015      404     380       41  14234
# 2         RT Ponting (AUS/ICC)  1995-2012      375     365       39  13704
# 3      ST Jayasuriya (Asia/SL)  1989-2011      445     433       18  13430
# 4   DPMD Jayawardene (Asia/SL)  1998-2015      448     418       39  12650
#
#   highest score average balls faced strike rate centuries half centuries  \
# 0          200*   44.83       21367       86.23        49             96
# 1           169   41.98       18048       78.86        25             93
# 2           164   42.03       17046       80.39        30             82
# 3           189   32.36       14725        91.2        28             68
# 4           144   33.37       16020       78.96        19             77
#
#   ducks    country
# 0    20      India
# 1    15  Sri Lanka
# ...

# %%
data.drop(columns='Player',inplace=True)

# %%
data[['start','end']]=data['Span'].str.split("-",expand=True)

# %%
data.head()
# Out:
#         Span  matches innings not outs   runs highest score average  \
# 0  1989-2012      463     452       41  18426          200*   44.83
# 1  2000-2015      404     380       41  14234           169   41.98
# 2  1995-2012      375     365       39  13704           164   42.03
# 3  1989-2011      445     433       18  13430           189   32.36
# 4  1998-2015      448     418       39  12650           144   33.37
#
#   balls faced strike rate centuries half centuries ducks    country start  \
# 0       21367       86.23        49             96    20      India  1989
# 1       18048       78.86        25             93    15  Sri Lanka  2000
# 2       17046       80.39        30             82    20  Australia  1995
# 3       14725        91.2        28             68    34  Sri Lanka  1989
# 4       16020       78.96        19             77    28  Sri Lanka  1998
#
#     end
# 0  2012
# 1  2015
# 2  2012
# 3  2011
# 4  2015

# %%
data['start']=data['start'].astype(int)

# %%
data['end']=data['end'].astype(int)

# %%
data['duration']=data['end']-data['start']

# %%
data.columns
# Out:
# Index(['Span', 'matches', 'innings', 'not outs', 'runs', 'highest score',
#        'average', 'balls faced', 'strike rate', 'centuries', 'half centuries',
#        'ducks', 'country', 'start', 'end', 'duration'],
#       dtype='object')

# %%
data.drop(columns='Span',inplace=True)

# %%
data.head()
# Out:
#    matches innings not outs   runs highest score average balls faced  \
# 0      463     452       41  18426          200*   44.83       21367
# 1      404     380       41  14234           169   41.98       18048
# 2      375     365       39  13704           164   42.03       17046
# 3      445     433       18  13430           189   32.36       14725
# 4      448     418       39  12650           144   33.37       16020
#
#   strike rate centuries half centuries ducks    country  start   end  duration
# 0       86.23        49             96    20      India   1989  2012        23
# 1       78.86        25             93    15  Sri Lanka   2000  2015        15
# 2       80.39        30             82    20  Australia   1995  2012        17
# 3        91.2        28             68    34  Sri Lanka   1989  2011        22
# 4       78.96        19             77    28  Sri Lanka   1998  2015        17

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 0 to 1283
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   matches         260 non-null    int64
#  1   innings         260 non-null    object
#  2   not outs        260 non-null    object
#  3   runs            260 non-null    object
#  4   highest score   260 non-null    object
#  5   average         260 non-null    object
#  6   balls faced     260 non-null    object
#  7   strike rate     260 non-null    object
#  8   centuries       260 non-null    object
#  9   half centuries  260 non-null    object
#  10  ducks           260 non-null    object
#  11  country         260 non-null    object
#  12  start           260 non-null    int32
#  13  end             260 non-null    int32
#  14  duration        260 non-null    int32
# dtypes: int32(3), int64(1), object(11)
# memory usage: 29.5+ KB

# %%
data['innings']=data['innings'].astype(int)

# %%
data[['not outs','runs','balls faced','centuries','half centuries','ducks']]=data[['not outs','runs','balls faced','centuries','half centuries','ducks']].astype(int)

# %%
data[['average','strike rate']]=data[['average','strike rate']].astype(float)

# %% [markdown]
# ### Format Here

# %%
data=data[data['centuries']>5]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 0 to 146
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   matches         80 non-null     int64
#  1   innings         80 non-null     int32
#  2   not outs        80 non-null     int32
#  3   runs            80 non-null     int32
#  4   highest score   80 non-null     object
#  5   average         80 non-null     float64
#  6   balls faced     80 non-null     int32
#  7   strike rate     80 non-null     float64
#  8   centuries       80 non-null     int32
#  9   half centuries  80 non-null     int32
#  10  ducks           80 non-null     int32
#  11  country         80 non-null     object
#  12  start           80 non-null     int32
#  13  end             80 non-null     int32
#  14  duration        80 non-null     int32
# dtypes: float64(2), int32(10), int64(1), object(2)
# memory usage: 6.9+ KB

# %%
data.head()
# Out:
#    matches  innings  not outs   runs highest score  average  balls faced  \
# 0      463      452        41  18426          200*    44.83        21367
# 1      404      380        41  14234           169    41.98        18048
# 2      375      365        39  13704           164    42.03        17046
# 3      445      433        18  13430           189    32.36        14725
# 4      448      418        39  12650           144    33.37        16020
#
#    strike rate  centuries  half centuries  ducks    country  start   end  \
# 0        86.23         49              96     20      India   1989  2012
# 1        78.86         25              93     15  Sri Lanka   2000  2015
# 2        80.39         30              82     20  Australia   1995  2012
# 3        91.20         28              68     34  Sri Lanka   1989  2011
# 4        78.96         19              77     28  Sri Lanka   1998  2015
#
#    duration
# 0        23
# 1        15
# 2        17
# 3        22
# 4        17

# %%
data['highest score']=data['highest score'].str.replace("*","").astype(int)

# %%
data.drop(columns=['start','end'],inplace=True)

# %%
data.head()
# Out:
#    matches  innings  not outs   runs  highest score  average  balls faced  \
# 0      463      452        41  18426            200    44.83        21367
# 1      404      380        41  14234            169    41.98        18048
# 2      375      365        39  13704            164    42.03        17046
# 3      445      433        18  13430            189    32.36        14725
# 4      448      418        39  12650            144    33.37        16020
#
#    strike rate  centuries  half centuries  ducks    country  duration
# 0        86.23         49              96     20      India        23
# 1        78.86         25              93     15  Sri Lanka        15
# 2        80.39         30              82     20  Australia        17
# 3        91.20         28              68     34  Sri Lanka        22
# 4        78.96         19              77     28  Sri Lanka        17

# %%
data['not out ratio']=(data['not outs']/data['innings']).round(2)

# %%
data['duck rate']=(data['ducks']/data['innings']).round(2)

# %%
data['century frequency']=(data['centuries']/data['innings']).round(2)

# %%
data['century conversion rate']=np.where(
    (data['centuries'] + data['half centuries']) == 0,
    0.0,
    data['centuries'] / (data['centuries'] + data['half centuries'])
).round(2)

# %%
data.head()
# Out:
#    matches  innings  not outs   runs  highest score  average  balls faced  \
# 0      463      452        41  18426            200    44.83        21367
# 1      404      380        41  14234            169    41.98        18048
# 2      375      365        39  13704            164    42.03        17046
# 3      445      433        18  13430            189    32.36        14725
# 4      448      418        39  12650            144    33.37        16020
#
#    strike rate  centuries  half centuries  ducks    country  duration  \
# 0        86.23         49              96     20      India        23
# 1        78.86         25              93     15  Sri Lanka        15
# 2        80.39         30              82     20  Australia        17
# 3        91.20         28              68     34  Sri Lanka        22
# 4        78.96         19              77     28  Sri Lanka        17
#
#    not out ratio  duck rate  century frequency  century conversion rate
# ...

# %%
data.drop(columns=['not outs','centuries','half centuries','ducks'],inplace=True)

# %%
data.head()
# Out:
#    matches  innings   runs  highest score  average  balls faced  strike rate  \
# 0      463      452  18426            200    44.83        21367        86.23
# 1      404      380  14234            169    41.98        18048        78.86
# 2      375      365  13704            164    42.03        17046        80.39
# 3      445      433  13430            189    32.36        14725        91.20
# 4      448      418  12650            144    33.37        16020        78.96
#
#      country  duration  not out ratio  duck rate  century frequency  \
# 0      India        23           0.09       0.04               0.11
# 1  Sri Lanka        15           0.11       0.04               0.07
# 2  Australia        17           0.11       0.05               0.08
# 3  Sri Lanka        22           0.04       0.08               0.06
# 4  Sri Lanka        17           0.09       0.07               0.05
#
#    century conversion rate
# 0                     0.34
# 1                     0.21
# ...

# %%
data['balls faced per innings']=(data['balls faced']/data['innings']).round(2)

# %%
data.drop('balls faced',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['matches', 'innings', 'runs', 'highest score', 'average', 'strike rate',
#        'country', 'duration', 'not out ratio', 'duck rate',
#        'century frequency', 'century conversion rate',
#        'balls faced per innings'],
#       dtype='object')

# %%
data.head()
# Out:
#    matches  innings   runs  highest score  average  strike rate    country  \
# 0      463      452  18426            200    44.83        86.23      India
# 1      404      380  14234            169    41.98        78.86  Sri Lanka
# 2      375      365  13704            164    42.03        80.39  Australia
# 3      445      433  13430            189    32.36        91.20  Sri Lanka
# 4      448      418  12650            144    33.37        78.96  Sri Lanka
#
#    duration  not out ratio  duck rate  century frequency  \
# 0        23           0.09       0.04               0.11
# 1        15           0.11       0.04               0.07
# 2        17           0.11       0.05               0.08
# 3        22           0.04       0.08               0.06
# 4        17           0.09       0.07               0.05
#
#    century conversion rate  balls faced per innings
# 0                     0.34                    47.27
# 1                     0.21                    47.49
# ...

# %%
data.to_csv(r"C:\Users\Rano's PC\Machine\💻data-science-projects\cricket talent prediction\cricket data cleaned.csv",index=False)

# %%
data.columns
# Out:
# Index(['matches', 'innings', 'runs', 'highest score', 'average', 'strike rate',
#        'country', 'duration', 'not out ratio', 'duck rate',
#        'century frequency', 'century conversion rate',
#        'balls faced per innings'],
#       dtype='object')

# %% [markdown]
# ## Creating of Model

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import cosine_similarity

# %%
numerical_cols = ['matches', 'innings', 'runs', 'highest score', 'average',
                  'strike rate', 'duration', 'not out ratio', 'duck rate',
                  'century frequency', 'century conversion rate', 'balls faced per innings']
categorical_cols = ['country']

# Build MinMaxScaler pipeline
minmax_preprocessor = ColumnTransformer([
    ('num', MinMaxScaler(), numerical_cols),
    ('cat', OneHotEncoder(), categorical_cols)
])

# %%
pipeline = Pipeline([
    ('preprocessor', minmax_preprocessor)
])

# %%
transformed_data = pipeline.fit_transform(data)

# %%
pipeline.fit(data)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['matches', 'innings', 'runs',
#                                                    'highest score', 'average',
#                                                    'strike rate', 'duration',
#                                                    'not out ratio', 'duck rate',
#                                                    'century frequency',
#                                                    'century conversion rate',
#                                                    'balls faced per innings']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['country'])]))])

# %%
elite_transformed = pipeline.transform(data)

# %%
new_player_data = {
    'matches': [350],
    'innings': [297],
    'runs': [10773],
    'highest score': [183],
    'average': [50.57],
    'strike rate': [87.56],
    'country': ['India'],
    'duration': [15],
    'not out ratio': [0.28],
    'duck rate': [0.03],
    'century frequency': [0.03],
    'century conversion rate': [0.12],
    'balls faced per innings': [41.42]
}
new_player = pd.DataFrame(new_player_data)
new_player_transformed = pipeline.transform(new_player)

# %%
similarities = cosine_similarity(new_player_transformed, elite_transformed)[0]
average_similarity = similarities.mean()
scaled_score = round(average_similarity * 100, 2)

# %%
print("Cosine Similarity Talent Score (0–100):", scaled_score)
# Out:
# Cosine Similarity Talent Score (0–100): 59.06

# %%
def classify_talent_score(score):
    """
    Classify player based on cosine similarity talent score (0–70 scale).
    """
    if score >= 60:
        return 'Future Top Player 🌟'
    elif score >= 50:
        return 'Promising Talent 🟡'
    elif score >= 30:
        return 'Needs Development ⚪'
    else:
        return 'Not Close Yet 🔴'

# %%
print(classify_talent_score(scaled_score))
# Out:
# Promising Talent 🟡

# %%
import dill  # or use pickle if preferred

# Save all necessary objects
with open("talent_model.pkl", "wb") as f:
    dill.dump({
        'pipeline': pipeline,
        'elite_data': elite_transformed,
        'countries': data['country'].unique().tolist()
    }, f)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.0
